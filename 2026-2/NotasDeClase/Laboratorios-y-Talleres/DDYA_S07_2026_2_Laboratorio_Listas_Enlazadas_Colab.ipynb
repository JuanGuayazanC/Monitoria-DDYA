# %% [markdown]
# # DDYA | Laboratorio de listas enlazadas, pilas y colas
#
# **Python | Google Colab | Informe individual**
# **Escuela Colombiana de Ingeniería Julio Garavito**
# **Profesor:** Sebastián Camilo Martínez Reyes
#
# En este laboratorio modificarás una lista enlazada simple para convertirla en una lista doblemente enlazada y la utilizarás como representación interna de una pila y una cola. El objetivo es comprender la relación entre la estructura interna de una clase y las operaciones que puede realizar.

# %% [markdown]
# ## Indicaciones de trabajo y entrega
#
# 1. Selecciona **Archivo > Guardar una copia en Drive** y trabaja sobre tu propia copia.
# 2. Completa tus datos en la primera celda editable.
# 3. Lee cada enunciado antes de modificar el código.
# 4. No modifiques los enunciados ni las celdas marcadas como bloqueadas.
# 5. Ejecuta las celdas en orden y conserva las salidas visibles.
# 6. Agrega pruebas propias para los casos normales y los casos límite.
# 7. El informe debe presentarse en este cuaderno de **Google Colab**.
# 8. Entrega el enlace del Colab con permisos de lectura.

# %%
# Completa tus datos.
nombre = ""
carne = ""
grupo = "G05 o G014"

print("Estudiante:", nombre or "PENDIENTE")
print("Carné:", carne or "PENDIENTE")
print("Grupo:", grupo)

# %% [markdown]
# ## 1. Análisis de diseño
#
# Antes de programar, explica con tus palabras la diferencia entre atributos y métodos. Identifica qué parte corresponde a la sección estructural y cuál a la sección comportamental.
#
# Responde también:
#
# - ¿Qué información debe guardar un nodo?
# - ¿Qué información debe guardar una lista?
# - ¿Qué referencias deben ser coherentes en una lista doblemente enlazada?
# - ¿Cómo se conservarán las políticas FIFO y LIFO?

# %%
# Escribe aquí tu análisis de diseño.
analisis = ""

# %% [markdown]
# ## 2. Código base y método `delete`
#
# Usa `LinkedLists (1).py` como referencia. Completa el método `delete` y prueba los casos de eliminar la cabeza, un nodo intermedio, la cola, un valor inexistente, un elemento único y un elemento de una lista vacía.
#
# Verifica que `head`, `tail` y `len` queden actualizados después de cada operación.

# %%
class Node:
    def __init__(self, value=None):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.len = 0

    def append(self, value):
        # Completa o adapta este método según tu diseño.
        pass

    def delete(self, value):
        # Implementa este método. No olvides todos los casos límite.
        pass

    def find(self, value):
        current = self.head
        while current is not None:
            if current.value == value:
                return current
            current = current.next
        return None

    def values(self):
        result = []
        current = self.head
        while current is not None:
            result.append(current.value)
            current = current.next
        return result

    def __str__(self):
        return str(self.values())

# %%
# Pruebas para delete. Agrega más casos propios.
lista = LinkedList()
for valor in [10, 20, 30, 40]:
    lista.append(valor)

print("Inicial:", lista, "len =", lista.len)
# lista.delete(10)
# lista.delete(30)
# lista.delete(40)
# lista.delete(999)
# print("Final:", lista, "len =", lista.len)

# %% [markdown]
# ## 3. Lista doblemente enlazada
#
# Modifica `Node` para agregar `prev`. Actualiza las operaciones necesarias para que cada nodo pueda recorrer la lista hacia adelante y hacia atrás.
#
# Implementa o adapta: `insert`, `update`, `delete`, eliminación de duplicados y unión de dos listas. Documenta qué referencias cambian en cada caso límite.

# %%
# Reescribe aquí Node y LinkedList como lista doblemente enlazada.
# Incluye una función de validación de invariantes.

class DoublyNode:
    def __init__(self, value=None):
        self.value = value
        self.prev = None
        self.next = None

# Implementa aquí tu LinkedList doble.

# %%
# Prueba recorrido hacia adelante y hacia atrás.
# Verifica: primer.prev is None y último.next is None.
# Incluye lista vacía, un elemento, varios elementos y duplicados.

def verificar_invariantes(lista):
    # Completa esta función. Debe devolver True o lanzar un error claro.
    pass

# %% [markdown]
# ## 4. `Queue` y `Stack` usando `LinkedList`
#
# Implementa las dos clases usando una instancia de `LinkedList` en el atributo `data`.
#
# - `Queue`: `Enqueue` agrega al final y `Dequeue` retira del frente. Debe respetar FIFO.
# - `Stack`: `Push` agrega al tope y `Pop` retira el tope. Debe respetar LIFO.
#
# Define qué ocurre al retirar de una estructura vacía y prueba esa decisión.

# %%
class Queue:
    def __init__(self):
        self.data = LinkedList()

    def Enqueue(self, value):
        # Implementa FIFO usando self.data.
        pass

    def Dequeue(self):
        # Implementa FIFO y define el caso de estructura vacía.
        pass

class Stack:
    def __init__(self):
        self.data = LinkedList()

    def Push(self, value):
        # Implementa LIFO usando self.data.
        pass

    def Pop(self):
        # Implementa LIFO y define el caso de estructura vacía.
        pass

# %%
# Prueba de FIFO y LIFO. Explica el resultado observado.
# queue = Queue()
# for persona in ["Ana", "Carlos", "Luis"]:
#     queue.Enqueue(persona)
# print(queue.Dequeue())

# stack = Stack()
# for libro in ["Algoritmos", "Python", "Estructuras"]:
#     stack.Push(libro)
# print(stack.Pop())

# %% [markdown]
# ## 5. Programa principal de demostración
#
# Escribe un programa principal para demostrar una cola de banco o cine, una pila de libros o tareas y las operaciones de la lista doble. La salida debe permitir observar las operaciones realizadas, los estados relevantes y el resultado final.

# %%
# Escribe aquí tu programa principal.
def main():
    pass

# main()

# %% [markdown]
# ## 6. Conclusiones
#
# Explica qué aprendiste sobre: atributos y métodos, referencias `prev` y `next`, casos límite, complejidad de las operaciones y políticas FIFO y LIFO. Compara la lista simple con la lista doblemente enlazada.

# %%
# Escribe aquí tus conclusiones.
conclusiones = ""

# %% [markdown]
# ## Lista de verificación antes de entregar
#
# - [ ] Completé mis datos y trabajé sobre una copia propia.
# - [ ] Implementé y probé `delete` en todos los casos límite.
# - [ ] Implementé `prev` y validé los enlaces dobles.
# - [ ] Implementé insert, update, delete, duplicados y unión.
# - [ ] `Queue` y `Stack` tienen un atributo `data` de tipo `LinkedList`.
# - [ ] Verifiqué FIFO, LIFO y estructuras vacías.
# - [ ] Incluí pruebas propias y sus resultados.
# - [ ] Incluí el programa principal y las conclusiones.
# - [ ] El enlace del Colab tiene permisos de lectura.
